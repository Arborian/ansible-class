# %%
cd ~/src/Classes/Ansible/
# Out:
# /Users/rick446/src/Classes/Ansible

# %% [markdown]
# # Fact caching to speed up playbooks
#
# At the beginning of each play, you might have noticed:
#
# ```
# TASK [Gathering Facts] **********************
# ```
#
# If your facts don't change much, we can speed this up quite a bit by enabling *fact caching* in `ansible.cfg`. There are several back-ends for fact caching; one of the simplest is `jsonfile`:

# %% [markdown]
# ```
# fact_caching = jsonfile
# fact_caching_connection = ./cachedir
# ```

# %% [markdown]
# Once we have fact caching set up, every host on which the `setup` module runs will cache its facts in the `cachedir` as a JSON file.

# %%
# %%bash
# ansible all -m setup
# ls -lh cachedir
# Out:
# arborian-04.class.arborian.com | SUCCESS => {
#     "ansible_facts": {
#         "ansible_all_ipv4_addresses": [
#             "45.55.20.52",
#             "10.12.0.7"
#         ],
#         "ansible_all_ipv6_addresses": [
#             "fe80::8ca4:c1ff:fe34:d3af"
#         ],
#         "ansible_apparmor": {
#             "status": "enabled"
#         },
#         "ansible_architecture": "x86_64",
#         "ansible_bios_date": "11/03/2016",
#         "ansible_bios_version": "20161103",
#         "ansible_cmdline": {
#             "BOOT_IMAGE": "/boot/vmlinuz-4.4.0-93-generic",
#             "console": "ttyS0",
#             "ro": true,
#             "root": "LABEL=cloudimg-rootfs"
#         },
#         "ansible_date_time": {
#             "date": "2017-10-12",
#             "day": "12",
#             "epoch": "1507768539",
#             "hour": "00",
#             "iso8601": "2017-10-12T00:35:39Z",
#             "iso8601_basic": "20171012T003539143510",
#             "iso8601_basic_short": "20171012T003539",
#             "iso8601_micro": "2017-10-12T00:35:39.143756Z",
#             "minute": "35",
#             "month": "10",
#             "second": "39",
#             "time": "00:35:39",
#             "tz": "UTC",
#             "tz_offset": "+0000",
#             "weekday": "Thursday",
#             "weekday_number": "4",
#             "weeknumber": "41",
#             "year": "2017"
#         },
#         "ansible_default_ipv4": {
#             "address": "45.55.20.52",
#             "alias": "eth0",
#             "broadcast": "45.55.31.255",
#             "gateway": "45.55.0.1",
#             "interface": "eth0",
#             "macaddress": "8e:a4:c1:34:d3:af",
#             "mtu": 1500,
#             "netmask": "255.255.224.0",
#             "network": "45.55.0.0",
#             "type": "ether"
#         },
#         "ansible_default_ipv6": {},
#         "ansible_device_links": {
#             "ids": {},
#             "labels": {
#                 "vda1": [
#                     "cloudimg-rootfs"
#                 ],
#                 "vda15": [
#                     "UEFI"
#                 ]
#             },
#             "masters": {},
#             "uuids": {
#                 "vda1": [
#                     "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#                 ],
#                 "vda15": [
#                     "29D4-9379"
#                 ]
#             }
#         },
#         "ansible_devices": {
#             "loop0": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop1": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop2": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop3": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop4": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop5": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop6": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop7": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "vda": {
#                 "holders": [],
#                 "host": "SCSI storage controller: Red Hat, Inc Virtio block device",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {
#                     "vda1": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [
#                                 "cloudimg-rootfs"
#                             ],
#                             "masters": [],
#                             "uuids": [
#                                 "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#                             ]
#                         },
#                         "sectors": "41715679",
#                         "sectorsize": 512,
#                         "size": "19.89 GB",
#                         "start": "227328",
#                         "uuid": "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#                     },
#                     "vda14": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "8192",
#                         "sectorsize": 512,
#                         "size": "4.00 MB",
#                         "start": "2048",
#                         "uuid": null
#                     },
#                     "vda15": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [
#                                 "UEFI"
#                             ],
#                             "masters": [],
#                             "uuids": [
#                                 "29D4-9379"
#                             ]
#                         },
#                         "sectors": "217088",
#                         "sectorsize": 512,
#                         "size": "106.00 MB",
#                         "start": "10240",
#                         "uuid": "29D4-9379"
#                     }
#                 },
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "41943040",
#                 "sectorsize": "512",
#                 "size": "20.00 GB",
#                 "support_discard": "0",
#                 "vendor": "0x1af4",
#                 "virtual": 1
#             }
#         },
#         "ansible_distribution": "Ubuntu",
#         "ansible_distribution_file_parsed": true,
#         "ansible_distribution_file_path": "/etc/os-release",
#         "ansible_distribution_file_variety": "Debian",
#         "ansible_distribution_major_version": "16",
#         "ansible_distribution_release": "xenial",
#         "ansible_distribution_version": "16.04",
#         "ansible_dns": {
#             "nameservers": [
#                 "8.8.8.8",
#                 "8.8.4.4"
#             ]
#         },
#         "ansible_domain": "",
#         "ansible_effective_group_id": 1001,
#         "ansible_effective_user_id": 1001,
#         "ansible_env": {
#             "HOME": "/home/rick",
#             "LANG": "en_US.UTF-8",
#             "LOGNAME": "rick",
#             "MAIL": "/var/mail/rick",
#             "PATH": "/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games",
#             "PWD": "/home/rick",
#             "SHELL": "/bin/bash",
#             "SHLVL": "1",
#             "SSH_AUTH_SOCK": "/tmp/ssh-dq5rpJyyqL/agent.8157",
#             "SSH_CLIENT": "12.130.117.128 61003 22",
#             "SSH_CONNECTION": "12.130.117.128 61003 45.55.20.52 22",
#             "SSH_TTY": "/dev/pts/0",
#             "TERM": "xterm-color",
#             "USER": "rick",
#             "XDG_RUNTIME_DIR": "/run/user/1001",
#             "XDG_SESSION_ID": "158",
#             "_": "/bin/sh"
#         },
#         "ansible_eth0": {
#             "active": true,
#             "device": "eth0",
#             "features": {
#                 "busy_poll": "on [fixed]",
#                 "fcoe_mtu": "off [fixed]",
#                 "generic_receive_offload": "on",
#                 "generic_segmentation_offload": "on",
#                 "highdma": "on [fixed]",
#                 "hw_tc_offload": "off [fixed]",
#                 "l2_fwd_offload": "off [fixed]",
#                 "large_receive_offload": "off [fixed]",
#                 "loopback": "off [fixed]",
#                 "netns_local": "off [fixed]",
#                 "ntuple_filters": "off [fixed]",
#                 "receive_hashing": "off [fixed]",
#                 "rx_all": "off [fixed]",
#                 "rx_checksumming": "on [fixed]",
#                 "rx_fcs": "off [fixed]",
#                 "rx_vlan_filter": "on [fixed]",
#                 "rx_vlan_offload": "off [fixed]",
#                 "rx_vlan_stag_filter": "off [fixed]",
#                 "rx_vlan_stag_hw_parse": "off [fixed]",
#                 "scatter_gather": "on",
#                 "tcp_segmentation_offload": "on",
#                 "tx_checksum_fcoe_crc": "off [fixed]",
#                 "tx_checksum_ip_generic": "on",
#                 "tx_checksum_ipv4": "off [fixed]",
#                 "tx_checksum_ipv6": "off [fixed]",
#                 "tx_checksum_sctp": "off [fixed]",
#                 "tx_checksumming": "on",
#                 "tx_fcoe_segmentation": "off [fixed]",
#                 "tx_gre_segmentation": "off [fixed]",
#                 "tx_gso_robust": "on [fixed]",
#                 "tx_ipip_segmentation": "off [fixed]",
#                 "tx_lockless": "off [fixed]",
#                 "tx_nocache_copy": "off",
#                 "tx_scatter_gather": "on",
#                 "tx_scatter_gather_fraglist": "off [fixed]",
#                 "tx_sit_segmentation": "off [fixed]",
#                 "tx_tcp6_segmentation": "on",
#                 "tx_tcp_ecn_segmentation": "on",
#                 "tx_tcp_segmentation": "on",
#                 "tx_udp_tnl_segmentation": "off [fixed]",
#                 "tx_vlan_offload": "off [fixed]",
#                 "tx_vlan_stag_hw_insert": "off [fixed]",
#                 "udp_fragmentation_offload": "on",
#                 "vlan_challenged": "off [fixed]"
#             },
#             "hw_timestamp_filters": [],
#             "ipv4": {
#                 "address": "45.55.20.52",
#                 "broadcast": "45.55.31.255",
#                 "netmask": "255.255.224.0",
#                 "network": "45.55.0.0"
#             },
#             "ipv4_secondaries": [
#                 {
#                     "address": "10.12.0.7",
#                     "broadcast": "10.12.255.255",
#                     "netmask": "255.255.0.0",
#                     "network": "10.12.0.0"
#                 }
#             ],
#             "ipv6": [
#                 {
#                     "address": "fe80::8ca4:c1ff:fe34:d3af",
#                     "prefix": "64",
#                     "scope": "link"
#                 }
#             ],
#             "macaddress": "8e:a4:c1:34:d3:af",
#             "mtu": 1500,
#             "pciid": "virtio0",
#             "promisc": false,
#             "speed": -1,
#             "timestamping": [
#                 "tx_software",
#                 "rx_software",
#                 "software"
#             ],
#             "type": "ether"
#         },
#         "ansible_fips": false,
#         "ansible_form_factor": "Other",
#         "ansible_fqdn": "arborian-04",
#         "ansible_hostname": "arborian-04",
#         "ansible_interfaces": [
#             "lo",
#             "eth0"
#         ],
#         "ansible_kernel": "4.4.0-93-generic",
#         "ansible_lo": {
#             "active": true,
#             "device": "lo",
#             "features": {
#                 "busy_poll": "off [fixed]",
#                 "fcoe_mtu": "off [fixed]",
#                 "generic_receive_offload": "on",
#                 "generic_segmentation_offload": "on",
#                 "highdma": "on [fixed]",
#                 "hw_tc_offload": "off [fixed]",
#                 "l2_fwd_offload": "off [fixed]",
#                 "large_receive_offload": "off [fixed]",
#                 "loopback": "on [fixed]",
#                 "netns_local": "on [fixed]",
#                 "ntuple_filters": "off [fixed]",
#                 "receive_hashing": "off [fixed]",
#                 "rx_all": "off [fixed]",
#                 "rx_checksumming": "on [fixed]",
#                 "rx_fcs": "off [fixed]",
#                 "rx_vlan_filter": "off [fixed]",
#                 "rx_vlan_offload": "off [fixed]",
#                 "rx_vlan_stag_filter": "off [fixed]",
#                 "rx_vlan_stag_hw_parse": "off [fixed]",
#                 "scatter_gather": "on",
#                 "tcp_segmentation_offload": "on",
#                 "tx_checksum_fcoe_crc": "off [fixed]",
#                 "tx_checksum_ip_generic": "on [fixed]",
#                 "tx_checksum_ipv4": "off [fixed]",
#                 "tx_checksum_ipv6": "off [fixed]",
#                 "tx_checksum_sctp": "on [fixed]",
#                 "tx_checksumming": "on",
#                 "tx_fcoe_segmentation": "off [fixed]",
#                 "tx_gre_segmentation": "off [fixed]",
#                 "tx_gso_robust": "off [fixed]",
#                 "tx_ipip_segmentation": "off [fixed]",
#                 "tx_lockless": "on [fixed]",
#                 "tx_nocache_copy": "off [fixed]",
#                 "tx_scatter_gather": "on [fixed]",
#                 "tx_scatter_gather_fraglist": "on [fixed]",
#                 "tx_sit_segmentation": "off [fixed]",
#                 "tx_tcp6_segmentation": "on",
#                 "tx_tcp_ecn_segmentation": "on",
#                 "tx_tcp_segmentation": "on",
#                 "tx_udp_tnl_segmentation": "off [fixed]",
#                 "tx_vlan_offload": "off [fixed]",
#                 "tx_vlan_stag_hw_insert": "off [fixed]",
#                 "udp_fragmentation_offload": "on",
#                 "vlan_challenged": "on [fixed]"
#             },
#             "hw_timestamp_filters": [],
#             "ipv4": {
#                 "address": "127.0.0.1",
#                 "broadcast": "host",
#                 "netmask": "255.0.0.0",
#                 "network": "127.0.0.0"
#             },
#             "ipv6": [
#                 {
#                     "address": "::1",
#                     "prefix": "128",
#                     "scope": "host"
#                 }
#             ],
#             "mtu": 65536,
#             "promisc": false,
#             "timestamping": [
#                 "rx_software",
#                 "software"
#             ],
#             "type": "loopback"
#         },
#         "ansible_local": {},
#         "ansible_lsb": {
#             "codename": "xenial",
#             "description": "Ubuntu 16.04.3 LTS",
#             "id": "Ubuntu",
#             "major_release": "16",
#             "release": "16.04"
#         },
#         "ansible_machine": "x86_64",
#         "ansible_machine_id": "d3bad226bf6f46a4a1ed5d55cfb59666",
#         "ansible_memfree_mb": 51,
#         "ansible_memory_mb": {
#             "nocache": {
#                 "free": 352,
#                 "used": 136
#             },
#             "real": {
#                 "free": 51,
#                 "total": 488,
#                 "used": 437
#             },
#             "swap": {
#                 "cached": 0,
#                 "free": 0,
#                 "total": 0,
#                 "used": 0
#             }
#         },
#         "ansible_memtotal_mb": 488,
#         "ansible_mounts": [
#             {
#                 "block_available": 4659611,
#                 "block_size": 4096,
#                 "block_total": 5036442,
#                 "block_used": 376831,
#                 "device": "/dev/vda1",
#                 "fstype": "ext4",
#                 "inode_available": 2461915,
#                 "inode_total": 2580480,
#                 "inode_used": 118565,
#                 "mount": "/",
#                 "options": "rw,relatime,data=ordered",
#                 "size_available": 19085766656,
#                 "size_total": 20629266432,
#                 "uuid": "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#             },
#             {
#                 "block_available": 206866,
#                 "block_size": 512,
#                 "block_total": 213716,
#                 "block_used": 6850,
#                 "device": "/dev/vda15",
#                 "fstype": "vfat",
#                 "inode_available": 0,
#                 "inode_total": 0,
#                 "inode_used": 0,
#                 "mount": "/boot/efi",
#                 "options": "rw,relatime,fmask=0022,dmask=0022,codepage=437,iocharset=iso8859-1,shortname=mixed,errors=remount-ro",
#                 "size_available": 105915392,
#                 "size_total": 109422592,
#                 "uuid": "29D4-9379"
#             }
#         ],
#         "ansible_nodename": "arborian-04",
#         "ansible_os_family": "Debian",
#         "ansible_pkg_mgr": "apt",
#         "ansible_processor": [
#             "0",
#             "GenuineIntel",
#             "Intel(R) Xeon(R) CPU E5-2630 0 @ 2.30GHz"
#         ],
#         "ansible_processor_cores": 1,
#         "ansible_processor_count": 1,
#         "ansible_processor_threads_per_core": 1,
#         "ansible_processor_vcpus": 1,
#         "ansible_product_name": "Droplet",
#         "ansible_product_serial": "NA",
#         "ansible_product_uuid": "NA",
#         "ansible_product_version": "20161103",
#         "ansible_python": {
#             "executable": "/usr/bin/python",
#             "has_sslcontext": true,
#             "type": "CPython",
#             "version": {
#                 "major": 2,
#                 "micro": 12,
#                 "minor": 7,
#                 "releaselevel": "final",
#                 "serial": 0
#             },
#             "version_info": [
#                 2,
#                 7,
#                 12,
#                 "final",
#                 0
#             ]
#         },
#         "ansible_python_version": "2.7.12",
#         "ansible_real_group_id": 1001,
#         "ansible_real_user_id": 1001,
#         "ansible_selinux": false,
#         "ansible_selinux_python_present": false,
#         "ansible_service_mgr": "systemd",
#         "ansible_ssh_host_key_dsa_public": "...",
#         "ansible_ssh_host_key_ecdsa_public": "AAAAE2VjZHNhLXNoYTItbmlzdHAyNTYAAAAIbmlzdHAyNTYAAABBBPU09AkUIBuuNtiSnxRV5QlmgHCKG9xJ0osC9uliuDECJN3L7Vo5FcCnWAeh0cdw01pp4GcjiTKMD+VAfP0dx9Y=",
#         "ansible_ssh_host_key_ed25519_public": "AAAAC3NzaC1lZDI1NTE5AAAAIBzRNvL6Rol5Ba4rijuqDdqtjdj5+anQA2++5ysWEGh+",
#         "ansible_ssh_host_key_rsa_public": "",
#         "ansible_swapfree_mb": 0,
#         "ansible_swaptotal_mb": 0,
#         "ansible_system": "Linux",
#         "ansible_system_capabilities": [
#             ""
#         ],
#         "ansible_system_capabilities_enforced": "True",
#         "ansible_system_vendor": "DigitalOcean",
#         "ansible_uptime_seconds": 453789,
#         "ansible_user_dir": "/home/rick",
#         "ansible_user_gecos": "",
#         "ansible_user_gid": 1001,
#         "ansible_user_id": "rick",
#         "ansible_user_shell": "/bin/bash",
#         "ansible_user_uid": 1001,
#         "ansible_userspace_architecture": "x86_64",
#         "ansible_userspace_bits": "64",
#         "ansible_virtualization_role": "host",
#         "ansible_virtualization_type": "kvm",
#         "gather_subset": [
#             "all"
#         ],
#         "module_setup": true
#     },
#     "changed": false,
#     "failed": false
# }
# arborian-02.class.arborian.com | SUCCESS => {
#     "ansible_facts": {
#         "ansible_all_ipv4_addresses": [
#             "104.236.182.188",
#             "10.12.0.5"
#         ],
#         "ansible_all_ipv6_addresses": [
#             "fe80::9413:7aff:feb4:a867"
#         ],
#         "ansible_apparmor": {
#             "status": "enabled"
#         },
#         "ansible_architecture": "x86_64",
#         "ansible_bios_date": "11/03/2016",
#         "ansible_bios_version": "20161103",
#         "ansible_cmdline": {
#             "BOOT_IMAGE": "/boot/vmlinuz-4.4.0-93-generic",
#             "console": "ttyS0",
#             "ro": true,
#             "root": "LABEL=cloudimg-rootfs"
#         },
#         "ansible_date_time": {
#             "date": "2017-10-12",
#             "day": "12",
#             "epoch": "1507768540",
#             "hour": "00",
#             "iso8601": "2017-10-12T00:35:40Z",
#             "iso8601_basic": "20171012T003540626826",
#             "iso8601_basic_short": "20171012T003540",
#             "iso8601_micro": "2017-10-12T00:35:40.627012Z",
#             "minute": "35",
#             "month": "10",
#             "second": "40",
#             "time": "00:35:40",
#             "tz": "UTC",
#             "tz_offset": "+0000",
#             "weekday": "Thursday",
#             "weekday_number": "4",
#             "weeknumber": "41",
#             "year": "2017"
#         },
#         "ansible_default_ipv4": {
#             "address": "104.236.182.188",
#             "alias": "eth0",
#             "broadcast": "104.236.191.255",
#             "gateway": "104.236.128.1",
#             "interface": "eth0",
#             "macaddress": "96:13:7a:b4:a8:67",
#             "mtu": 1500,
#             "netmask": "255.255.192.0",
#             "network": "104.236.128.0",
#             "type": "ether"
#         },
#         "ansible_default_ipv6": {},
#         "ansible_device_links": {
#             "ids": {},
#             "labels": {
#                 "vda1": [
#                     "cloudimg-rootfs"
#                 ],
#                 "vda15": [
#                     "UEFI"
#                 ]
#             },
#             "masters": {},
#             "uuids": {
#                 "vda1": [
#                     "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#                 ],
#                 "vda15": [
#                     "29D4-9379"
#                 ]
#             }
#         },
#         "ansible_devices": {
#             "loop0": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop1": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop2": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop3": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop4": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop5": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop6": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop7": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "0",
#                 "sectorsize": "512",
#                 "size": "0.00 Bytes",
#                 "support_discard": "0",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "vda": {
#                 "holders": [],
#                 "host": "SCSI storage controller: Red Hat, Inc Virtio block device",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {
#                     "vda1": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [
#                                 "cloudimg-rootfs"
#                             ],
#                             "masters": [],
#                             "uuids": [
#                                 "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#                             ]
#                         },
#                         "sectors": "41715679",
#                         "sectorsize": 512,
#                         "size": "19.89 GB",
#                         "start": "227328",
#                         "uuid": "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#                     },
#                     "vda14": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "8192",
#                         "sectorsize": 512,
#                         "size": "4.00 MB",
#                         "start": "2048",
#                         "uuid": null
#                     },
#                     "vda15": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [
#                                 "UEFI"
#                             ],
#                             "masters": [],
#                             "uuids": [
#                                 "29D4-9379"
#                             ]
#                         },
#                         "sectors": "217088",
#                         "sectorsize": 512,
#                         "size": "106.00 MB",
#                         "start": "10240",
#                         "uuid": "29D4-9379"
#                     }
#                 },
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "41943040",
#                 "sectorsize": "512",
#                 "size": "20.00 GB",
#                 "support_discard": "0",
#                 "vendor": "0x1af4",
#                 "virtual": 1
#             }
#         },
#         "ansible_distribution": "Ubuntu",
#         "ansible_distribution_file_parsed": true,
#         "ansible_distribution_file_path": "/etc/os-release",
#         "ansible_distribution_file_variety": "Debian",
#         "ansible_distribution_major_version": "16",
#         "ansible_distribution_release": "xenial",
#         "ansible_distribution_version": "16.04",
#         "ansible_dns": {
#             "nameservers": [
#                 "8.8.4.4",
#                 "8.8.8.8"
#             ]
#         },
#         "ansible_domain": "",
#         "ansible_effective_group_id": 1002,
#         "ansible_effective_user_id": 1002,
#         "ansible_env": {
#             "HOME": "/home/rick",
#             "LANG": "en_US.UTF-8",
#             "LOGNAME": "rick",
#             "MAIL": "/var/mail/rick",
#             "PATH": "/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games",
#             "PWD": "/home/rick",
#             "SHELL": "/bin/bash",
#             "SHLVL": "1",
#             "SSH_AUTH_SOCK": "/tmp/ssh-bpOoQUmGUp/agent.15058",
#             "SSH_CLIENT": "12.130.117.128 60999 22",
#             "SSH_CONNECTION": "12.130.117.128 60999 104.236.182.188 22",
#             "SSH_TTY": "/dev/pts/0",
#             "TERM": "xterm-color",
#             "USER": "rick",
#             "XDG_RUNTIME_DIR": "/run/user/1002",
#             "XDG_SESSION_ID": "181",
#             "_": "/bin/sh"
#         },
#         "ansible_eth0": {
#             "active": true,
#             "device": "eth0",
#             "features": {
#                 "busy_poll": "on [fixed]",
#                 "fcoe_mtu": "off [fixed]",
#                 "generic_receive_offload": "on",
#                 "generic_segmentation_offload": "on",
#                 "highdma": "on [fixed]",
#                 "hw_tc_offload": "off [fixed]",
#                 "l2_fwd_offload": "off [fixed]",
#                 "large_receive_offload": "off [fixed]",
#                 "loopback": "off [fixed]",
#                 "netns_local": "off [fixed]",
#                 "ntuple_filters": "off [fixed]",
#                 "receive_hashing": "off [fixed]",
#                 "rx_all": "off [fixed]",
#                 "rx_checksumming": "on [fixed]",
#                 "rx_fcs": "off [fixed]",
#                 "rx_vlan_filter": "on [fixed]",
#                 "rx_vlan_offload": "off [fixed]",
#                 "rx_vlan_stag_filter": "off [fixed]",
#                 "rx_vlan_stag_hw_parse": "off [fixed]",
#                 "scatter_gather": "on",
#                 "tcp_segmentation_offload": "on",
#                 "tx_checksum_fcoe_crc": "off [fixed]",
#                 "tx_checksum_ip_generic": "on",
#                 "tx_checksum_ipv4": "off [fixed]",
#                 "tx_checksum_ipv6": "off [fixed]",
#                 "tx_checksum_sctp": "off [fixed]",
#                 "tx_checksumming": "on",
#                 "tx_fcoe_segmentation": "off [fixed]",
#                 "tx_gre_segmentation": "off [fixed]",
#                 "tx_gso_robust": "on [fixed]",
#                 "tx_ipip_segmentation": "off [fixed]",
#                 "tx_lockless": "off [fixed]",
#                 "tx_nocache_copy": "off",
#                 "tx_scatter_gather": "on",
#                 "tx_scatter_gather_fraglist": "off [fixed]",
#                 "tx_sit_segmentation": "off [fixed]",
#                 "tx_tcp6_segmentation": "on",
#                 "tx_tcp_ecn_segmentation": "on",
#                 "tx_tcp_segmentation": "on",
#                 "tx_udp_tnl_segmentation": "off [fixed]",
#                 "tx_vlan_offload": "off [fixed]",
#                 "tx_vlan_stag_hw_insert": "off [fixed]",
#                 "udp_fragmentation_offload": "on",
#                 "vlan_challenged": "off [fixed]"
#             },
#             "hw_timestamp_filters": [],
#             "ipv4": {
#                 "address": "104.236.182.188",
#                 "broadcast": "104.236.191.255",
#                 "netmask": "255.255.192.0",
#                 "network": "104.236.128.0"
#             },
#             "ipv4_secondaries": [
#                 {
#                     "address": "10.12.0.5",
#                     "broadcast": "10.12.255.255",
#                     "netmask": "255.255.0.0",
#                     "network": "10.12.0.0"
#                 }
#             ],
#             "ipv6": [
#                 {
#                     "address": "fe80::9413:7aff:feb4:a867",
#                     "prefix": "64",
#                     "scope": "link"
#                 }
#             ],
#             "macaddress": "96:13:7a:b4:a8:67",
#             "mtu": 1500,
#             "pciid": "virtio0",
#             "promisc": false,
#             "speed": -1,
#             "timestamping": [
#                 "tx_software",
#                 "rx_software",
#                 "software"
#             ],
#             "type": "ether"
#         },
#         "ansible_fips": false,
#         "ansible_form_factor": "Other",
#         "ansible_fqdn": "arborian-02",
#         "ansible_hostname": "arborian-02",
#         "ansible_interfaces": [
#             "lo",
#             "eth0"
#         ],
#         "ansible_kernel": "4.4.0-93-generic",
#         "ansible_lo": {
#             "active": true,
#             "device": "lo",
#             "features": {
#                 "busy_poll": "off [fixed]",
#                 "fcoe_mtu": "off [fixed]",
#                 "generic_receive_offload": "on",
#                 "generic_segmentation_offload": "on",
#                 "highdma": "on [fixed]",
#                 "hw_tc_offload": "off [fixed]",
#                 "l2_fwd_offload": "off [fixed]",
#                 "large_receive_offload": "off [fixed]",
#                 "loopback": "on [fixed]",
#                 "netns_local": "on [fixed]",
#                 "ntuple_filters": "off [fixed]",
#                 "receive_hashing": "off [fixed]",
#                 "rx_all": "off [fixed]",
#                 "rx_checksumming": "on [fixed]",
#                 "rx_fcs": "off [fixed]",
#                 "rx_vlan_filter": "off [fixed]",
#                 "rx_vlan_offload": "off [fixed]",
#                 "rx_vlan_stag_filter": "off [fixed]",
#                 "rx_vlan_stag_hw_parse": "off [fixed]",
#                 "scatter_gather": "on",
#                 "tcp_segmentation_offload": "on",
#                 "tx_checksum_fcoe_crc": "off [fixed]",
#                 "tx_checksum_ip_generic": "on [fixed]",
#                 "tx_checksum_ipv4": "off [fixed]",
#                 "tx_checksum_ipv6": "off [fixed]",
#                 "tx_checksum_sctp": "on [fixed]",
#                 "tx_checksumming": "on",
#                 "tx_fcoe_segmentation": "off [fixed]",
#                 "tx_gre_segmentation": "off [fixed]",
#                 "tx_gso_robust": "off [fixed]",
#                 "tx_ipip_segmentation": "off [fixed]",
#                 "tx_lockless": "on [fixed]",
#                 "tx_nocache_copy": "off [fixed]",
#                 "tx_scatter_gather": "on [fixed]",
#                 "tx_scatter_gather_fraglist": "on [fixed]",
#                 "tx_sit_segmentation": "off [fixed]",
#                 "tx_tcp6_segmentation": "on",
#                 "tx_tcp_ecn_segmentation": "on",
#                 "tx_tcp_segmentation": "on",
#                 "tx_udp_tnl_segmentation": "off [fixed]",
#                 "tx_vlan_offload": "off [fixed]",
#                 "tx_vlan_stag_hw_insert": "off [fixed]",
#                 "udp_fragmentation_offload": "on",
#                 "vlan_challenged": "on [fixed]"
#             },
#             "hw_timestamp_filters": [],
#             "ipv4": {
#                 "address": "127.0.0.1",
#                 "broadcast": "host",
#                 "netmask": "255.0.0.0",
#                 "network": "127.0.0.0"
#             },
#             "ipv6": [
#                 {
#                     "address": "::1",
#                     "prefix": "128",
#                     "scope": "host"
#                 }
#             ],
#             "mtu": 65536,
#             "promisc": false,
#             "timestamping": [
#                 "rx_software",
#                 "software"
#             ],
#             "type": "loopback"
#         },
#         "ansible_local": {},
#         "ansible_lsb": {
#             "codename": "xenial",
#             "description": "Ubuntu 16.04.3 LTS",
#             "id": "Ubuntu",
#             "major_release": "16",
#             "release": "16.04"
#         },
#         "ansible_machine": "x86_64",
#         "ansible_machine_id": "1c2d9c61803f4a829560145c1b158999",
#         "ansible_memfree_mb": 111,
#         "ansible_memory_mb": {
#             "nocache": {
#                 "free": 353,
#                 "used": 135
#             },
#             "real": {
#                 "free": 111,
#                 "total": 488,
#                 "used": 377
#             },
#             "swap": {
#                 "cached": 0,
#                 "free": 0,
#                 "total": 0,
#                 "used": 0
#             }
#         },
#         "ansible_memtotal_mb": 488,
#         "ansible_mounts": [
#             {
#                 "block_available": 4655385,
#                 "block_size": 4096,
#                 "block_total": 5036442,
#                 "block_used": 381057,
#                 "device": "/dev/vda1",
#                 "fstype": "ext4",
#                 "inode_available": 2461518,
#                 "inode_total": 2580480,
#                 "inode_used": 118962,
#                 "mount": "/",
#                 "options": "rw,relatime,data=ordered",
#                 "size_available": 19068456960,
#                 "size_total": 20629266432,
#                 "uuid": "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#             },
#             {
#                 "block_available": 206866,
#                 "block_size": 512,
#                 "block_total": 213716,
#                 "block_used": 6850,
#                 "device": "/dev/vda15",
#                 "fstype": "vfat",
#                 "inode_available": 0,
#                 "inode_total": 0,
#                 "inode_used": 0,
#                 "mount": "/boot/efi",
#                 "options": "rw,relatime,fmask=0022,dmask=0022,codepage=437,iocharset=iso8859-1,shortname=mixed,errors=remount-ro",
#                 "size_available": 105915392,
#                 "size_total": 109422592,
#                 "uuid": "29D4-9379"
#             }
#         ],
#         "ansible_nodename": "arborian-02",
#         "ansible_os_family": "Debian",
#         "ansible_pkg_mgr": "apt",
#         "ansible_processor": [
#             "0",
#             "GenuineIntel",
#             "Intel(R) Xeon(R) CPU E5-2630 0 @ 2.30GHz"
#         ],
#         "ansible_processor_cores": 1,
#         "ansible_processor_count": 1,
#         "ansible_processor_threads_per_core": 1,
#         "ansible_processor_vcpus": 1,
#         "ansible_product_name": "Droplet",
#         "ansible_product_serial": "NA",
#         "ansible_product_uuid": "NA",
#         "ansible_product_version": "20161103",
#         "ansible_python": {
#             "executable": "/usr/bin/python",
#             "has_sslcontext": true,
#             "type": "CPython",
#             "version": {
#                 "major": 2,
#                 "micro": 12,
#                 "minor": 7,
#                 "releaselevel": "final",
#                 "serial": 0
#             },
#             "version_info": [
#                 2,
#                 7,
#                 12,
#                 "final",
#                 0
#             ]
#         },
#         "ansible_python_version": "2.7.12",
#         "ansible_real_group_id": 1002,
#         "ansible_real_user_id": 1002,
#         "ansible_selinux": {
#             "status": "disabled"
#         },
#         "ansible_selinux_python_present": true,
#         "ansible_service_mgr": "systemd",
#         "ansible_ssh_host_key_dsa_public": "...",
#         "ansible_ssh_host_key_ecdsa_public": "AAAAE2VjZHNhLXNoYTItbmlzdHAyNTYAAAAIbmlzdHAyNTYAAABBBD21JL2CF/jUyHNVK26TpM1j7DwmSwLXjqkAfIdWdGj8fXU2FcOSJy47+rsF/J6PeZOzwXyJFko4zmGUqFJeGIk=",
#         "ansible_ssh_host_key_ed25519_public": "AAAAC3NzaC1lZDI1NTE5AAAAIOT9+8PUN5iXUOr9UqoMlW39jDjc/nJyK3MOLg7gqfvU",
#         "ansible_ssh_host_key_rsa_public": "",
#         "ansible_swapfree_mb": 0,
#         "ansible_swaptotal_mb": 0,
#         "ansible_system": "Linux",
#         "ansible_system_capabilities": [
#             ""
#         ],
#         "ansible_system_capabilities_enforced": "True",
#         "ansible_system_vendor": "DigitalOcean",
#         "ansible_uptime_seconds": 453797,
#         "ansible_user_dir": "/home/rick",
#         "ansible_user_gecos": "",
#         "ansible_user_gid": 1002,
#         "ansible_user_id": "rick",
#         "ansible_user_shell": "/bin/bash",
#         "ansible_user_uid": 1002,
#         "ansible_userspace_architecture": "x86_64",
#         "ansible_userspace_bits": "64",
#         "ansible_virtualization_role": "host",
#         "ansible_virtualization_type": "kvm",
#         "gather_subset": [
#             "all"
#         ],
#         "module_setup": true
#     },
# ...
#                 },
#                 "model": null,
#                 "partitions": {
#                     "vda1": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [
#                                 "cloudimg-rootfs"
#                             ],
#                             "masters": [],
#                             "uuids": [
#                                 "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#                             ]
#                         },
#                         "sectors": "41715679",
#                         "sectorsize": 512,
#                         "size": "19.89 GB",
#                         "start": "227328",
#                         "uuid": "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#                     },
#                     "vda14": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "8192",
#                         "sectorsize": 512,
#                         "size": "4.00 MB",
#                         "start": "2048",
#                         "uuid": null
#                     },
#                     "vda15": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [
#                                 "UEFI"
#                             ],
#                             "masters": [],
#                             "uuids": [
#                                 "29D4-9379"
#                             ]
#                         },
#                         "sectors": "217088",
#                         "sectorsize": 512,
#                         "size": "106.00 MB",
#                         "start": "10240",
#                         "uuid": "29D4-9379"
#                     }
#                 },
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "",
#                 "sectors": "41943040",
#                 "sectorsize": "512",
#                 "size": "20.00 GB",
#                 "support_discard": "0",
#                 "vendor": "0x1af4",
#                 "virtual": 1
#             }
#         },
#         "ansible_distribution": "Ubuntu",
#         "ansible_distribution_file_parsed": true,
#         "ansible_distribution_file_path": "/etc/os-release",
#         "ansible_distribution_file_variety": "Debian",
#         "ansible_distribution_major_version": "16",
#         "ansible_distribution_release": "xenial",
#         "ansible_distribution_version": "16.04",
#         "ansible_dns": {
#             "nameservers": [
#                 "8.8.4.4",
#                 "8.8.8.8"
#             ]
#         },
#         "ansible_domain": "",
#         "ansible_effective_group_id": 1001,
#         "ansible_effective_user_id": 1001,
#         "ansible_env": {
#             "HOME": "/home/rick",
#             "LANG": "en_US.UTF-8",
#             "LOGNAME": "rick",
#             "MAIL": "/var/mail/rick",
#             "PATH": "/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games",
#             "PWD": "/home/rick",
#             "SHELL": "/bin/bash",
#             "SHLVL": "1",
#             "SSH_AUTH_SOCK": "/tmp/ssh-wz6F9H3Tgs/agent.8283",
#             "SSH_CLIENT": "12.130.117.128 61004 22",
#             "SSH_CONNECTION": "12.130.117.128 61004 45.55.20.232 22",
#             "SSH_TTY": "/dev/pts/0",
#             "TERM": "xterm-color",
#             "USER": "rick",
#             "XDG_RUNTIME_DIR": "/run/user/1001",
#             "XDG_SESSION_ID": "157",
#             "_": "/bin/sh"
#         },
#         "ansible_eth0": {
#             "active": true,
#             "device": "eth0",
#             "features": {
#                 "busy_poll": "on [fixed]",
#                 "fcoe_mtu": "off [fixed]",
#                 "generic_receive_offload": "on",
#                 "generic_segmentation_offload": "on",
#                 "highdma": "on [fixed]",
#                 "hw_tc_offload": "off [fixed]",
#                 "l2_fwd_offload": "off [fixed]",
#                 "large_receive_offload": "off [fixed]",
#                 "loopback": "off [fixed]",
#                 "netns_local": "off [fixed]",
#                 "ntuple_filters": "off [fixed]",
#                 "receive_hashing": "off [fixed]",
#                 "rx_all": "off [fixed]",
#                 "rx_checksumming": "on [fixed]",
#                 "rx_fcs": "off [fixed]",
#                 "rx_vlan_filter": "on [fixed]",
#                 "rx_vlan_offload": "off [fixed]",
#                 "rx_vlan_stag_filter": "off [fixed]",
#                 "rx_vlan_stag_hw_parse": "off [fixed]",
#                 "scatter_gather": "on",
#                 "tcp_segmentation_offload": "on",
#                 "tx_checksum_fcoe_crc": "off [fixed]",
#                 "tx_checksum_ip_generic": "on",
#                 "tx_checksum_ipv4": "off [fixed]",
#                 "tx_checksum_ipv6": "off [fixed]",
#                 "tx_checksum_sctp": "off [fixed]",
#                 "tx_checksumming": "on",
#                 "tx_fcoe_segmentation": "off [fixed]",
#                 "tx_gre_segmentation": "off [fixed]",
#                 "tx_gso_robust": "on [fixed]",
#                 "tx_ipip_segmentation": "off [fixed]",
#                 "tx_lockless": "off [fixed]",
#                 "tx_nocache_copy": "off",
#                 "tx_scatter_gather": "on",
#                 "tx_scatter_gather_fraglist": "off [fixed]",
#                 "tx_sit_segmentation": "off [fixed]",
#                 "tx_tcp6_segmentation": "on",
#                 "tx_tcp_ecn_segmentation": "on",
#                 "tx_tcp_segmentation": "on",
#                 "tx_udp_tnl_segmentation": "off [fixed]",
#                 "tx_vlan_offload": "off [fixed]",
#                 "tx_vlan_stag_hw_insert": "off [fixed]",
#                 "udp_fragmentation_offload": "on",
#                 "vlan_challenged": "off [fixed]"
#             },
#             "hw_timestamp_filters": [],
#             "ipv4": {
#                 "address": "45.55.20.232",
#                 "broadcast": "45.55.31.255",
#                 "netmask": "255.255.224.0",
#                 "network": "45.55.0.0"
#             },
#             "ipv4_secondaries": [
#                 {
#                     "address": "10.12.0.9",
#                     "broadcast": "10.12.255.255",
#                     "netmask": "255.255.0.0",
#                     "network": "10.12.0.0"
#                 }
#             ],
#             "ipv6": [
#                 {
#                     "address": "fe80::9ca6:aff:fe5f:ef74",
#                     "prefix": "64",
#                     "scope": "link"
#                 }
#             ],
#             "macaddress": "9e:a6:0a:5f:ef:74",
#             "mtu": 1500,
#             "pciid": "virtio0",
#             "promisc": false,
#             "speed": -1,
#             "timestamping": [
#                 "tx_software",
#                 "rx_software",
#                 "software"
#             ],
#             "type": "ether"
#         },
#         "ansible_fips": false,
#         "ansible_form_factor": "Other",
#         "ansible_fqdn": "arborian-06",
#         "ansible_hostname": "arborian-06",
#         "ansible_interfaces": [
#             "lo",
#             "eth0"
#         ],
#         "ansible_kernel": "4.4.0-93-generic",
#         "ansible_lo": {
#             "active": true,
#             "device": "lo",
#             "features": {
#                 "busy_poll": "off [fixed]",
#                 "fcoe_mtu": "off [fixed]",
#                 "generic_receive_offload": "on",
#                 "generic_segmentation_offload": "on",
#                 "highdma": "on [fixed]",
#                 "hw_tc_offload": "off [fixed]",
#                 "l2_fwd_offload": "off [fixed]",
#                 "large_receive_offload": "off [fixed]",
#                 "loopback": "on [fixed]",
#                 "netns_local": "on [fixed]",
#                 "ntuple_filters": "off [fixed]",
#                 "receive_hashing": "off [fixed]",
#                 "rx_all": "off [fixed]",
#                 "rx_checksumming": "on [fixed]",
#                 "rx_fcs": "off [fixed]",
#                 "rx_vlan_filter": "off [fixed]",
#                 "rx_vlan_offload": "off [fixed]",
#                 "rx_vlan_stag_filter": "off [fixed]",
#                 "rx_vlan_stag_hw_parse": "off [fixed]",
#                 "scatter_gather": "on",
#                 "tcp_segmentation_offload": "on",
#                 "tx_checksum_fcoe_crc": "off [fixed]",
#                 "tx_checksum_ip_generic": "on [fixed]",
#                 "tx_checksum_ipv4": "off [fixed]",
#                 "tx_checksum_ipv6": "off [fixed]",
#                 "tx_checksum_sctp": "on [fixed]",
#                 "tx_checksumming": "on",
#                 "tx_fcoe_segmentation": "off [fixed]",
#                 "tx_gre_segmentation": "off [fixed]",
#                 "tx_gso_robust": "off [fixed]",
#                 "tx_ipip_segmentation": "off [fixed]",
#                 "tx_lockless": "on [fixed]",
#                 "tx_nocache_copy": "off [fixed]",
#                 "tx_scatter_gather": "on [fixed]",
#                 "tx_scatter_gather_fraglist": "on [fixed]",
#                 "tx_sit_segmentation": "off [fixed]",
#                 "tx_tcp6_segmentation": "on",
#                 "tx_tcp_ecn_segmentation": "on",
#                 "tx_tcp_segmentation": "on",
#                 "tx_udp_tnl_segmentation": "off [fixed]",
#                 "tx_vlan_offload": "off [fixed]",
#                 "tx_vlan_stag_hw_insert": "off [fixed]",
#                 "udp_fragmentation_offload": "on",
#                 "vlan_challenged": "on [fixed]"
#             },
#             "hw_timestamp_filters": [],
#             "ipv4": {
#                 "address": "127.0.0.1",
#                 "broadcast": "host",
#                 "netmask": "255.0.0.0",
#                 "network": "127.0.0.0"
#             },
#             "ipv6": [
#                 {
#                     "address": "::1",
#                     "prefix": "128",
#                     "scope": "host"
#                 }
#             ],
#             "mtu": 65536,
#             "promisc": false,
#             "timestamping": [
#                 "rx_software",
#                 "software"
#             ],
#             "type": "loopback"
#         },
#         "ansible_local": {},
#         "ansible_lsb": {
#             "codename": "xenial",
#             "description": "Ubuntu 16.04.3 LTS",
#             "id": "Ubuntu",
#             "major_release": "16",
#             "release": "16.04"
#         },
#         "ansible_machine": "x86_64",
#         "ansible_machine_id": "bcf2f67456e748f69f6c12d61a55b695",
#         "ansible_memfree_mb": 49,
#         "ansible_memory_mb": {
#             "nocache": {
#                 "free": 330,
#                 "used": 158
#             },
#             "real": {
#                 "free": 49,
#                 "total": 488,
#                 "used": 439
#             },
#             "swap": {
#                 "cached": 0,
#                 "free": 0,
#                 "total": 0,
#                 "used": 0
#             }
#         },
#         "ansible_memtotal_mb": 488,
#         "ansible_mounts": [
#             {
#                 "block_available": 4659410,
#                 "block_size": 4096,
#                 "block_total": 5036442,
#                 "block_used": 377032,
#                 "device": "/dev/vda1",
#                 "fstype": "ext4",
#                 "inode_available": 2461921,
#                 "inode_total": 2580480,
#                 "inode_used": 118559,
#                 "mount": "/",
#                 "options": "rw,relatime,data=ordered",
#                 "size_available": 19084943360,
#                 "size_total": 20629266432,
#                 "uuid": "e559f3b8-10a8-4224-b3a5-048dd68cc72f"
#             },
#             {
#                 "block_available": 206866,
#                 "block_size": 512,
#                 "block_total": 213716,
#                 "block_used": 6850,
#                 "device": "/dev/vda15",
#                 "fstype": "vfat",
#                 "inode_available": 0,
#                 "inode_total": 0,
#                 "inode_used": 0,
#                 "mount": "/boot/efi",
#                 "options": "rw,relatime,fmask=0022,dmask=0022,codepage=437,iocharset=iso8859-1,shortname=mixed,errors=remount-ro",
#                 "size_available": 105915392,
#                 "size_total": 109422592,
#                 "uuid": "29D4-9379"
#             }
#         ],
#         "ansible_nodename": "arborian-06",
#         "ansible_os_family": "Debian",
#         "ansible_pkg_mgr": "apt",
#         "ansible_processor": [
#             "0",
#             "GenuineIntel",
#             "Intel(R) Xeon(R) CPU E5-2630L v2 @ 2.40GHz"
#         ],
#         "ansible_processor_cores": 1,
#         "ansible_processor_count": 1,
#         "ansible_processor_threads_per_core": 1,
#         "ansible_processor_vcpus": 1,
#         "ansible_product_name": "Droplet",
#         "ansible_product_serial": "NA",
#         "ansible_product_uuid": "NA",
#         "ansible_product_version": "20161103",
#         "ansible_python": {
#             "executable": "/usr/bin/python",
#             "has_sslcontext": true,
#             "type": "CPython",
#             "version": {
#                 "major": 2,
#                 "micro": 12,
#                 "minor": 7,
#                 "releaselevel": "final",
#                 "serial": 0
#             },
#             "version_info": [
#                 2,
#                 7,
#                 12,
#                 "final",
#                 0
#             ]
#         },
#         "ansible_python_version": "2.7.12",
#         "ansible_real_group_id": 1001,
#         "ansible_real_user_id": 1001,
#         "ansible_selinux": false,
#         "ansible_selinux_python_present": false,
#         "ansible_service_mgr": "systemd",
#         "ansible_ssh_host_key_dsa_public": "...",
#         "ansible_ssh_host_key_ecdsa_public": "AAAAE2VjZHNhLXNoYTItbmlzdHAyNTYAAAAIbmlzdHAyNTYAAABBBNzAvn537b32GW2IXSOQxBfIIGu8rqR2o6Qq18+/0cmb010UCBFXwW3kNF/d81ds3mDmovy+nuiOzTrO93t9Mzg=",
#         "ansible_ssh_host_key_ed25519_public": "AAAAC3NzaC1lZDI1NTE5AAAAIPA7zs+KYaoRAy605NlDRWFVjH4wRIFU+DJ89CPNXzEf",
#         "ansible_ssh_host_key_rsa_public": "",
#         "ansible_swapfree_mb": 0,
#         "ansible_swaptotal_mb": 0,
#         "ansible_system": "Linux",
#         "ansible_system_capabilities": [
#             ""
#         ],
#         "ansible_system_capabilities_enforced": "True",
#         "ansible_system_vendor": "DigitalOcean",
#         "ansible_uptime_seconds": 453817,
#         "ansible_user_dir": "/home/rick",
#         "ansible_user_gecos": "",
#         "ansible_user_gid": 1001,
#         "ansible_user_id": "rick",
#         "ansible_user_shell": "/bin/bash",
#         "ansible_user_uid": 1001,
#         "ansible_userspace_architecture": "x86_64",
#         "ansible_userspace_bits": "64",
#         "ansible_virtualization_role": "host",
#         "ansible_virtualization_type": "kvm",
#         "gather_subset": [
#             "all"
#         ],
#         "module_setup": true
#     },
#     "changed": false,
#     "failed": false
# }
# total 288
# -rw-r--r--  1 rick446  staff    21K Oct 11 20:35 arborian-01.class.arborian.com
# -rw-r--r--  1 rick446  staff    21K Oct 11 20:35 arborian-02.class.arborian.com
# -rw-r--r--  1 rick446  staff    21K Oct 11 20:35 arborian-03.class.arborian.com
# -rw-r--r--  1 rick446  staff    21K Oct 11 20:35 arborian-04.class.arborian.com
# -rw-r--r--  1 rick446  staff    21K Oct 11 20:35 arborian-05.class.arborian.com
# -rw-r--r--  1 rick446  staff    21K Oct 11 20:36 arborian-06.class.arborian.com

# %% [markdown]
# # Lab: Speed test
#
# Ensure that fact caching is turned on in `ansible.cfg`
#
# Make sure all the hosts have their facts cached:
#
# `ansible all -m setup`
#
# Use the `time` command to compare the runtime of `playbooks/setup-stack.yaml` and `playbooks/setup-stack-cached.yaml`.
